# %% [markdown]
# # HOUSING: PRICE PREDICTION

# %% [markdown]
# # Problem Statement

# %% [markdown]
# A US-based housing company named Surprise Housing has decided to enter the Australian market. The company uses
# data analytics to purchase houses at a price below their actual values and flip them at a higher price. For the same
# purpose, the company has collected a data set from the sale of houses in Australia.
#
# The company is looking at prospective properties to buy houses to enter the market.So i have to build a model
# using Machine Learning in order to predict the actual value of the prospective properties and decide whether to invest
# in them or not. For this company wants to know:
# • Which variables are important to predict the price of variable?
# • How do these variables describe the price of the house?
#
#
# Business Goal:
#
# I require to model the price of houses with the available independent variables. This model will then be used
# by the management to understand how exactly the prices vary with the variables. They can accordingly manipulate the
# strategy of the firm and concentrate on areas that will yield high returns. Further, the model will be a good way for the
# management to understand the pricing dynamics of a new market.

# %% [markdown]
# First we have to make model ready for train dataset then we have to predict our test dataset.

# %% [markdown]
# # Train Dataset

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load dataset
df=pd.read_csv("C:/Users/Lenovo/OneDrive/Desktop/Download/Project-Housing_splitted/train.csv")
pd.pandas.set_option('display.max_columns',100)#used to see all the columns in the dataset
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          nan     4928   Pave   NaN      IR1
# 1     889          20       RL     95.00000    15865   Pave   NaN      IR1
# 2     793          60       RL     92.00000     9920   Pave   NaN      IR1
# 3     110          20       RL    105.00000    11751   Pave   NaN      IR1
# 4     422          20       RL          nan    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          nan     9819   Pave   NaN      IR1
# 1164  554          20       RL     67.00000     8777   Pave   NaN      Reg
# 1165  196         160       RL     24.00000     2280   Pave   NaN      Reg
# 1166   31          70  C (all)     50.00000     8500   Pave  Pave      Reg
# 1167  617          60       RL          nan     7861   Pave   NaN      IR1
#
# ...

# %%
#checking dimension
df.shape
# Out:
# (1168, 81)

# %%
print(df.columns)#about columns
print(df.dtypes)#about dataset types
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
# ...

# %%
#description about dataset
df.describe()
# Out:
#               Id  MSSubClass  LotFrontage      LotArea  OverallQual  \
# count 1168.00000  1168.00000    954.00000   1168.00000   1168.00000
# mean   724.13613    56.76798     70.98847  10484.74914      6.10445
# std    416.15988    41.94065     24.82875   8957.44231      1.39015
# min      1.00000    20.00000     21.00000   1300.00000      1.00000
# 25%    360.50000    20.00000     60.00000   7621.50000      5.00000
# 50%    714.50000    50.00000     70.00000   9522.50000      6.00000
# 75%   1079.50000    70.00000     80.00000  11515.50000      7.00000
# max   1460.00000   190.00000    313.00000 164660.00000     10.00000
#
#        OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# count   1168.00000 1168.00000    1168.00000  1161.00000  1168.00000
# mean       5.59589 1970.93065    1984.75856   102.31008   444.72603
# std        1.12434   30.14526      20.78519   182.59561   462.66478
# min        1.00000 1875.00000    1950.00000     0.00000     0.00000
# ...

# %%
df.isnull().sum()#checking null values in the dataset
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# There are so many null values present in the dataset.So i have to make deal with null values after exploratory data analysis

# %% [markdown]
# # Data Analysis

# %%
cat_columns=[i for i in df.columns if df[i].dtypes=='O']#extract object type feature
num_columns=[i for i in df.columns if df[i].dtypes!='O']#extract numerical type feature

# %%
df[cat_columns]
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Mod
# 2          RL   Pave   NaN      IR1         Lvl    AllPub   CulDSac       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1163       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 1164       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1165       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 1166  C (all)   Pave  Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1167       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
df[num_columns]
# Out:
#        Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     127         120          nan     4928            6            5
# 1     889          20     95.00000    15865            8            6
# 2     793          60     92.00000     9920            7            5
# 3     110          20    105.00000    11751            6            6
# 4     422          20          nan    16635            6            7
# ...   ...         ...          ...      ...          ...          ...
# 1163  289          20          nan     9819            5            5
# 1164  554          20     67.00000     8777            4            5
# 1165  196         160     24.00000     2280            6            6
# 1166   31          70     50.00000     8500            4            4
# 1167  617          60          nan     7861            6            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
yr=[i for i in df.columns if 'Yr' in i or 'Year' in i]
df[yr]
# Out:
#       YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0          1976          1976   1977.00000    2007
# 1          1970          1970   1970.00000    2007
# 2          1996          1997   1997.00000    2007
# 3          1977          1977   1977.00000    2010
# 4          1977          2000   1977.00000    2009
# ...         ...           ...          ...     ...
# 1163       1967          1967   1970.00000    2010
# 1164       1949          2003   2002.00000    2009
# 1165       1976          1976   1976.00000    2009
# 1166       1920          1950   1920.00000    2008
# 1167       2002          2003   2002.00000    2006
#
# [1168 rows x 4 columns]

# %% [markdown]
# we have total 81 features from which 4 columns that belongs to years,34 columns belong to numerical features and 43 columns belong to catagorical features

# %%
#checking unique values of features containing years
for i in df[yr].columns:
    print('unique value for',i,df[i].nunique())
# Out:
# unique value for YearBuilt 110
# unique value for YearRemodAdd 61
# unique value for GarageYrBlt 97
# unique value for YrSold 5

# %%
df['YrSold'].unique()
# Out:
# array([2007, 2010, 2009, 2006, 2008], dtype=int64)

# %%
# We will check whether there is a relation between year the house is sold and the sales price
df.groupby('YrSold')['SalePrice'].median().plot()#taking median due to outlier present as we see in df.describe()
plt.xlabel('Year Sold')
plt.ylabel('Median House Price')
plt.title("House Price vs YearSold")
# Out:
# Text(0.5, 1.0, 'House Price vs YearSold')

# %% [markdown]
# It shows that house sold in 2007 have high price compared to other years sold.It is showing negative relationship as we year increases but we know that as year increases price of houses increases.so we have to do more exploration.

# %%
#we have to see relationship of saleprice with yr columns
for i in df[yr]:
    sns.scatterplot(df[i],df['SalePrice'])
    plt.show()

# %% [markdown]
# we clearly see that as year increases price of houses increases.

# %%
df['YrSold'].value_counts()
# Out:
# 2007    264
# 2009    260
# 2006    254
# 2008    248
# 2010    142
# Name: YrSold, dtype: int64

# %% [markdown]
# # Catagorical Variable

# %% [markdown]
# we have to see all  catagorical features unique values and their count below.

# %%
for i in df[cat_columns]:
    sns.countplot(df[i])
    plt.show()
    print(df[i].value_counts())
    print('unique value counts',df[i].nunique())
# Out:
# RL         928
# RM         163
# FV          52
# RH          16
# C (all)      9
# Name: MSZoning, dtype: int64
# unique value counts 5
# Pave    1164
# Grvl       4
# Name: Street, dtype: int64
# unique value counts 2
# Grvl    41
# Pave    36
# Name: Alley, dtype: int64
# unique value counts 2
# Reg    740
# IR1    390
# IR2     32
# IR3      6
# Name: LotShape, dtype: int64
# unique value counts 4
# Lvl    1046
# Bnk      50
# HLS      42
# Low      30
# Name: LandContour, dtype: int64
# unique value counts 4
# AllPub    1168
# Name: Utilities, dtype: int64
# unique value counts 1
# Inside     842
# Corner     222
# CulDSac     69
# FR2         33
# FR3          2
# Name: LotConfig, dtype: int64
# unique value counts 5
# Gtl    1105
# Mod      51
# Sev      12
# Name: LandSlope, dtype: int64
# unique value counts 3
# NAmes      182
# CollgCr    118
# OldTown     86
# Edwards     83
# Somerst     68
# Gilbert     64
# NridgHt     61
# Sawyer      60
# NWAmes      59
# ...

# %%
#checking relationship of catagorical variables with sale price
for i in df[cat_columns]:
    df.groupby(i)['SalePrice'].median().plot.bar()
    plt.xlabel(i)
    plt.ylabel('Sale Price')
    plt.title('Relationship with SalePrice')
    plt.show()

# %% [markdown]
# Utilities column has only one value.so we may drop the column in feature selection column.

# %% [markdown]
# # Numerical Variables

# %%
# Numerical variables are of two types 1.discrete   2.continious.So we have to divide it.
discrete=[i for i in df[num_columns].columns if df[i].nunique()<25 and i not in yr]
continious=[i for i in df[num_columns].columns if df[i].nunique()>25 and i not in yr]

# %%
discrete
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
continious
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
df[discrete]
# Out:
#       MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0            120            6            5             0             0
# 1             20            8            6             0             1
# 2             60            7            5             0             1
# 3             20            6            6             0             0
# 4             20            6            7             0             0
# ...          ...          ...          ...           ...           ...
# 1163          20            5            5             0             0
# 1164          20            4            5             0             0
# 1165         160            6            6             0             0
# 1166          70            4            4             0             0
# 1167          60            6            5             0             1
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# ...

# %%
df[continious]
# Out:
#        Id  LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# 0     127          nan     4928     0.00000         120           0
# 1     889     95.00000    15865     0.00000         351         823
# 2     793     92.00000     9920     0.00000         862           0
# 3     110    105.00000    11751   480.00000         705           0
# 4     422          nan    16635   126.00000        1246           0
# ...   ...          ...      ...         ...         ...         ...
# 1163  289          nan     9819    31.00000         450           0
# 1164  554     67.00000     8777     0.00000           0           0
# 1165  196     24.00000     2280     0.00000         566           0
# 1166   31     50.00000     8500     0.00000           0           0
# 1167  617          nan     7861     0.00000         457           0
#
#       BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  \
# 0           958         1078       958         0        958         440
# ...

# %%
#Checking relationship of saleprice with discrete features
for i in df[discrete].columns:
    df.groupby(i)['SalePrice'].median().plot.bar()
    plt.ylabel('SalePrice')
    plt.show()

# %% [markdown]
# SalePrice varies directly with the Overall quality

# %%
for i in df[continious].columns:
    sns.scatterplot(df[i],df['SalePrice'])
    plt.show()

# %% [markdown]
# # Replacing Missing Values

# %% [markdown]
# # Catagorical columns

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df[cat_columns].isnull())
plt.show()

# %%
df[cat_columns].isnull().sum()
# Out:
# MSZoning            0
# Street              0
# Alley            1091
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          7
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           30
# BsmtCond           30
# BsmtExposure       31
# BsmtFinType1       30
# BsmtFinType2       31
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          0
# KitchenQual         0
# Functional          0
# FireplaceQu       551
# GarageType         64
# GarageFinish       64
# GarageQual         64
# GarageCond         64
# PavedDrive          0
# PoolQC           1161
# Fence             931
# MiscFeature      1124
# ...

# %% [markdown]
# We have to replace null values of catagorical column as we see in the data description file

# %%
df['Alley'].fillna('NA',inplace=True)#replace null values with NA as no alley acess
df['MasVnrType'].fillna('None',inplace=True)#replace null values with None
df['BsmtQual'].fillna('TA',inplace=True)#replace null values with mode of the column
df['BsmtCond'].fillna('TA',inplace=True)#replace null values with mode of the column
df['BsmtExposure'].fillna('No',inplace=True)#replace null values with mode of the column
df['BsmtFinType1'].fillna('Unf',inplace=True)#replace null values with mode of the column
df['BsmtFinType2'].fillna('Unf',inplace=True)#replace null values with mode of the column
df['FireplaceQu'].fillna('NA',inplace=True)#replace null values with NA(as not available) of the column
df['GarageType'].fillna('NA',inplace=True)#replace null values with NA(as not available) of the column
df['GarageFinish'].fillna('NA',inplace=True)#replace null values with NA(as garrage not available) of the column
df['GarageQual'].fillna('NA',inplace=True)#replace null values with NA(as garrage not available) of the column
df['GarageCond'].fillna('NA',inplace=True)#replace null values with NA(as garrage not available) of the column
df['PoolQC'].fillna('NA',inplace=True)#replace null values with NA(as pool not available) of the column
df['Fence'].fillna('NA',inplace=True)#replace null values with NA(as Fence not available) of the column
df['MiscFeature'].fillna('NA',inplace=True)#replace null values with NA(as not available)

# %% [markdown]
# # Year column

# %%
sns.heatmap(df[yr].isnull())

# %%
df[yr].isnull().sum()
# Out:
# YearBuilt        0
# YearRemodAdd     0
# GarageYrBlt     64
# YrSold           0
# dtype: int64

# %%
df['GarageYrBlt']=df['GarageYrBlt'].fillna(df.YearBuilt)#replce null values of garrage built column with the year house was built

# %% [markdown]
# # Discrete Variables

# %%
sns.heatmap(df[discrete].isnull())

# %% [markdown]
# There are no null values in discrete features

# %% [markdown]
# # Continious Variables

# %%
sns.heatmap(df[continious].isnull())

# %%
df[continious].isnull().sum()
# Out:
# Id                 0
# LotFrontage      214
# LotArea            0
# MasVnrArea         7
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# GrLivArea          0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# ScreenPorch        0
# SalePrice          0
# dtype: int64

# %%
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          nan     4928   Pave    NA      IR1
# 1     889          20       RL     95.00000    15865   Pave    NA      IR1
# 2     793          60       RL     92.00000     9920   Pave    NA      IR1
# 3     110          20       RL    105.00000    11751   Pave    NA      IR1
# 4     422          20       RL          nan    16635   Pave    NA      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          nan     9819   Pave    NA      IR1
# 1164  554          20       RL     67.00000     8777   Pave    NA      Reg
# 1165  196         160       RL     24.00000     2280   Pave    NA      Reg
# 1166   31          70  C (all)     50.00000     8500   Pave  Pave      Reg
# 1167  617          60       RL          nan     7861   Pave    NA      IR1
#
# ...

# %%
df['LotFrontage']=df['LotFrontage'].fillna(df['LotFrontage'].mean())#replace null values with their mean
df['MasVnrArea']=df['MasVnrArea'].fillna(df['MasVnrArea'].mean())#replace null values with their mean

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# I have replaced all the null values of the dataset.

# %% [markdown]
# # Checking Corelation of Numerical columns

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df[continious].corr(),annot=True)
plt.show()

# %%
df[continious].corr()['SalePrice']
# Out:
# Id              -0.02390
# LotFrontage      0.32378
# LotArea          0.24950
# MasVnrArea       0.46363
# BsmtFinSF1       0.36287
# BsmtFinSF2      -0.01015
# BsmtUnfSF        0.21572
# TotalBsmtSF      0.59504
# 1stFlrSF         0.58764
# 2ndFlrSF         0.33039
# GrLivArea        0.70730
# GarageArea       0.61900
# WoodDeckSF       0.31544
# OpenPorchSF      0.33950
# EnclosedPorch   -0.11500
# ScreenPorch      0.10028
# SalePrice        1.00000
# Name: SalePrice, dtype: float64

# %% [markdown]
# GrLivArea,GarageArea is highly positively corelated to saleprice

# %% [markdown]
# # Outlier detection

# %%
for i in df[continious].columns:
    sns.boxplot(df[continious][i])
    plt.show()

# %% [markdown]
# After looking at boxplot,we clearly see that some outliers are present in the dataset.So we have to remove these outliers

# %%
df[df['LotFrontage']>300]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 592   1299          60       RL    313.00000    63887   Pave    NA      IR3
# 1053   935          20       RL    313.00000    27650   Pave    NA      IR2
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 592          Bnk    AllPub    Corner       Gtl      Edwards      Feedr
# 1053         HLS    AllPub    Inside       Mod        NAmes       PosA
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 592        Norm     1Fam     2Story           10            5       2008
# 1053       Norm     1Fam     1Story            7            7       1960
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 592           2008       Hip  ClyTile      Stucco      Stucco      Stone
# 1053          2007      Flat  Tar&Grv     Wd Sdng     Wd Sdng       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# ...

# %%
df[df['LotArea']>140000]
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1038  250          50       RL     70.98847   159000   Pave    NA      IR2
# 1123  336         190       RL     70.98847   164660   Grvl    NA      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1038         Low    AllPub   CulDSac       Sev      ClearCr       Norm
# 1123         HLS    AllPub    Corner       Sev       Timber       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1038       Norm     1Fam     1.5Fin            6            7       1958
# 1123       Norm   2fmCon     1.5Fin            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1038          2006     Gable  CompShg     Wd Sdng     HdBoard     BrkCmn
# 1123          1965     Gable  CompShg     Plywood     Plywood       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# ...

# %%
df[df['1stFlrSF']>4000]
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 592  1299          60       RL    313.00000    63887   Pave    NA      IR3
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 592         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 592       Norm     1Fam     2Story           10            5       2008
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 592          2008       Hip  ClyTile      Stucco      Stucco      Stone
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 592   796.00000        Ex        TA      PConc       Ex       TA           Gd
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 592          GLQ        5644          Unf           0        466         6110
#
# ...

# %%
df[df['GrLivArea']>5000]
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 592  1299          60       RL    313.00000    63887   Pave    NA      IR3
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 592         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 592       Norm     1Fam     2Story           10            5       2008
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 592          2008       Hip  ClyTile      Stucco      Stucco      Stone
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 592   796.00000        Ex        TA      PConc       Ex       TA           Gd
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 592          GLQ        5644          Unf           0        466         6110
#
# ...

# %%
#So we have to drop these outlier rows 
df=df.drop([592,1038,1053,1123],axis=0)#drop outlier rows in the dataset
df=df.reset_index()#reindexing dataset
df=df.drop('index',axis=1)#drop index column of dataset
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL     70.98847     4928   Pave    NA      IR1
# 1     889          20       RL     95.00000    15865   Pave    NA      IR1
# 2     793          60       RL     92.00000     9920   Pave    NA      IR1
# 3     110          20       RL    105.00000    11751   Pave    NA      IR1
# 4     422          20       RL     70.98847    16635   Pave    NA      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1159  289          20       RL     70.98847     9819   Pave    NA      IR1
# 1160  554          20       RL     67.00000     8777   Pave    NA      Reg
# 1161  196         160       RL     24.00000     2280   Pave    NA      Reg
# 1162   31          70  C (all)     50.00000     8500   Pave  Pave      Reg
# 1163  617          60       RL     70.98847     7861   Pave    NA      IR1
#
# ...

# %%
dataloss=(4/1168)*100#after removing outliers
dataloss
#after removing outliers dataloss is 0.34%.so its negligible as compared to dataset
# Out:
# 0.3424657534246575

# %% [markdown]
# # Checking Skewness

# %%
for i in df[['LotFrontage','LotArea','1stFlrSF','GrLivArea','SalePrice']].columns:
    sns.distplot(df[['LotFrontage','LotArea','1stFlrSF','GrLivArea','SalePrice']][i])
    plt.show()

# %%
df[['LotFrontage','LotArea','1stFlrSF','GrLivArea','SalePrice']].skew()
# Out:
# LotFrontage   0.83754
# LotArea       6.79545
# 1stFlrSF      1.01825
# GrLivArea     1.15780
# SalePrice     1.96065
# dtype: float64

# %% [markdown]
# Some skewness is present .so we have to remove skewness by using power transform method and logarithmic transform

# %%
from sklearn.preprocessing import power_transform
df['LotFrontage']=power_transform(df[['LotFrontage']])
df['GrLivArea']=power_transform(df[['GrLivArea']])

# %%
df['LotArea']=np.log(df['LotArea'])
df['1stFlrSF']=np.log(df['1stFlrSF'])

# %%
#df['SalePrice']=np.log(df['SalePrice'])

# %%
df[['LotFrontage','LotArea','1stFlrSF','GrLivArea']].skew()
# Out:
# LotFrontage    0.13722
# LotArea       -0.56224
# 1stFlrSF       0.03862
# GrLivArea      0.00101
# dtype: float64

# %%
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL      0.07239  8.50269   Pave    NA      IR1
# 1     889          20       RL      1.20189  9.67187   Pave    NA      IR1
# 2     793          60       RL      1.06692  9.20231   Pave    NA      IR1
# 3     110          20       RL      1.64109  9.37169   Pave    NA      IR1
# 4     422          20       RL      0.07239  9.71926   Pave    NA      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1159  289          20       RL      0.07239  9.19207   Pave    NA      IR1
# 1160  554          20       RL     -0.12777  9.07989   Pave    NA      Reg
# 1161  196         160       RL     -2.68063  7.73193   Pave    NA      Reg
# 1162   31          70  C (all)     -1.03439  9.04782   Pave  Pave      Reg
# 1163  617          60       RL      0.07239  8.96967   Pave    NA      IR1
#
# ...

# %% [markdown]
# Skewness has been removed from above features

# %% [markdown]
# Convert Catogorical variable to numeric

# %%
from sklearn.preprocessing import OrdinalEncoder
od=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes==object:
        df[i]=od.fit_transform(df[[i]])

# %% [markdown]
# We have to drop id column as it has unique values and drop utilities column as this column has only single value

# %%
df=df.drop(['Id','Utilities'],axis=1)
df
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street   Alley  LotShape  \
# 0            120   3.00000      0.07239  8.50269 1.00000 1.00000   0.00000
# 1             20   3.00000      1.20189  9.67187 1.00000 1.00000   0.00000
# 2             60   3.00000      1.06692  9.20231 1.00000 1.00000   0.00000
# 3             20   3.00000      1.64109  9.37169 1.00000 1.00000   0.00000
# 4             20   3.00000      0.07239  9.71926 1.00000 1.00000   0.00000
# ...          ...       ...          ...      ...     ...     ...       ...
# 1159          20   3.00000      0.07239  9.19207 1.00000 1.00000   0.00000
# 1160          20   3.00000     -0.12777  9.07989 1.00000 1.00000   3.00000
# 1161         160   3.00000     -2.68063  7.73193 1.00000 1.00000   3.00000
# 1162          70   0.00000     -1.03439  9.04782 1.00000 2.00000   3.00000
# 1163          60   3.00000      0.07239  8.96967 1.00000 1.00000   0.00000
#
# ...

# %% [markdown]
# Divide dependent and independent variable

# %%
x=df.drop('SalePrice',axis=1)
y=df['SalePrice']

# %%
from sklearn.preprocessing import MinMaxScaler#scaling independent columns 
scaler=MinMaxScaler()
x=scaler.fit_transform(x)

# %% [markdown]
# # Model Creation

# %% [markdown]
# finding best random_state

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
maxacc=0
maxrs=0
lr=LinearRegression()
for i  in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=i)
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    acc=r2_score(y_test,y_pred)
    if acc>maxacc:
        maxacc=acc
        maxrs=i
print('best accuracy score is',maxacc,'on random_state',maxrs)
# Out:
# best accuracy score is 0.9267238648916273 on random_state 59

# %%
#So our best random_state is 59.WE have to use random_state 59 in different regression algorithms to choose a good model.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=59)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
acc=r2_score(y_test,y_pred)
acc
# Out:
# 0.9267238648916273

# %%
from sklearn.linear_model import Lasso
from sklearn.svm import SVR
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from xgboost import XGBRegressor

# %%
ls=Lasso()
svr=SVR()
rd=Ridge()
els=ElasticNet()
ex=XGBRegressor()

# %%
model=[lr,ls,svr,rd,els,ex]

# %%
for i in model:
    i.fit(x_train,y_train)
    y_pred=i.predict(x_test)
    print(i)
    print(r2_score(y_test,y_pred))
    print(mean_squared_error(y_test,y_pred))
# Out:
# LinearRegression()
# 0.9267238648916273
# 393664143.5917082
# Lasso()
# 0.926849976843782
# 392986627.595972
# SVR()
# -0.0951325514544874
# 5883421899.232688
# Ridge()
# 0.9256394523375655
# 399489974.0447404
# ElasticNet()
# 0.5920990524490574
# 2191381640.8357534
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)
# 0.872275990902445
# 686176510.034621

# %% [markdown]
# Ensemble technique

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_Pred=rf.predict(x_test)
acc=r2_score(y_test,y_pred)
acc
# Out:
# 0.872275990902445

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)
y_Pred=gb.predict(x_test)
acc=r2_score(y_test,y_pred)
acc
# Out:
# 0.872275990902445

# %%
from sklearn.ensemble import ExtraTreesRegressor
ext=ExtraTreesRegressor()
ext.fit(x_train,y_train)
y_Pred=ext.predict(x_test)
acc=r2_score(y_test,y_pred)
acc
# Out:
# 0.872275990902445

# %% [markdown]
# We have to check if lassoregression model is overfitting to the dataset or not by using cross_val_score

# %%
from sklearn.model_selection import cross_val_score
for j in range(3,10):
    cv=cross_val_score(ls,x,y,cv=j)
    print('accuracy',cv.mean(),'for cv=',j )
# Out:
# accuracy 0.8187160894842527 for cv= 3
# accuracy 0.8106537756625923 for cv= 4
# accuracy 0.8200911836370798 for cv= 5
# accuracy 0.8203065267510627 for cv= 6
# accuracy 0.8062386445683162 for cv= 7
# accuracy 0.8223940723160615 for cv= 8
# accuracy 0.8166267754971978 for cv= 9

# %% [markdown]
# best cvscore is 82.23% on cv=8

# %% [markdown]
# From using above models we see that lasso is giving good accuracy compared to all regression and ensemble algorithm.So we have to Hyperparameter Tuning in Lasso Regression.

# %% [markdown]
# # Hyperparameter Tuning in Ridge Regression

# %%
from sklearn.model_selection import GridSearchCV

# %%
par=np.logspace(-4, 0, 30)#choosing alpha value

# %%
par
# Out:
# array([1.00000000e-04, 1.37382380e-04, 1.88739182e-04, 2.59294380e-04,
#        3.56224789e-04, 4.89390092e-04, 6.72335754e-04, 9.23670857e-04,
#        1.26896100e-03, 1.74332882e-03, 2.39502662e-03, 3.29034456e-03,
#        4.52035366e-03, 6.21016942e-03, 8.53167852e-03, 1.17210230e-02,
#        1.61026203e-02, 2.21221629e-02, 3.03919538e-02, 4.17531894e-02,
#        5.73615251e-02, 7.88046282e-02, 1.08263673e-01, 1.48735211e-01,
#        2.04335972e-01, 2.80721620e-01, 3.85662042e-01, 5.29831691e-01,
#        7.27895384e-01, 1.00000000e+00])

# %%
ls=Lasso()
ls.fit(x_train,y_train)
y_pred=ls.predict(x_test)
acc=r2_score(y_test,y_pred)
acc
# Out:
# 0.926849976843782

# %%
params = {'alpha':par}
gscv=GridSearchCV(rg,params,scoring='neg_mean_absolute_error',cv=8,n_jobs=-1)
gscv.fit(x_train,y_train)
print(gscv.best_params_)
print(gscv.best_score_)
# Out:
# {'alpha': 1.0}
# -20188.93163228786

# %%
from sklearn.linear_model import Lasso
ls=Lasso(alpha=1,normalize=True)
ls.fit(x_train,y_train)
y_pred=ls.predict(x_test)
acc=r2_score(y_test,y_pred)
acc
# Out:
# 0.9272604939330309

# %% [markdown]
# After hyperparameter tuning of Lasso regression my accuracy becomes 92.72% from 92.68%.So for this dataset Lassoregression is the best model

# %%
#Plotting y_test and y_pred
plt.figure(figsize=(22,7))
plt.scatter(x=y_test,y=y_pred,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual SalePrice',fontsize=20)
plt.ylabel('Predicted SalePrice',fontsize=20)
plt.title('Best fit line',fontsize=25)
plt.show()

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(ls,'price.pkl')
# Out:
# ['price.pkl']

# %% [markdown]
# # Test dataset

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load dataset
df1=pd.read_csv("C:/Users/Lenovo/OneDrive/Desktop/Download/Project-Housing_splitted/test.csv")
pd.pandas.set_option('display.max_columns',100)#used to see all the columns in the dataset
df1
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL     86.00000    14157   Pave   NaN      IR1
# 1    1018         120       RL          nan     5814   Pave   NaN      IR1
# 2     929          20       RL          nan    11838   Pave   NaN      Reg
# 3    1148          70       RL     75.00000    12000   Pave   NaN      Reg
# 4    1227          60       RL     86.00000    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL     78.00000    10206   Pave   NaN      Reg
# 288  1048          20       RL     57.00000     9245   Pave   NaN      IR2
# 289    17          20       RL          nan    11241   Pave   NaN      IR1
# 290   523          50       RM     50.00000     5000   Pave   NaN      Reg
# 291  1379         160       RM     21.00000     1953   Pave   NaN      Reg
#
# ...

# %%
#checking dimension
df1.shape
# Out:
# (292, 80)

# %%
print(df1.columns)#about columns
print(df1.dtypes)#about dataset types
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             292 non-null    int64
#  1   MSSubClass     292 non-null    int64
#  2   MSZoning       292 non-null    object
#  3   LotFrontage    247 non-null    float64
#  4   LotArea        292 non-null    int64
#  5   Street         292 non-null    object
#  6   Alley          14 non-null     object
#  7   LotShape       292 non-null    object
#  8   LandContour    292 non-null    object
#  9   Utilities      292 non-null    object
#  10  LotConfig      292 non-null    object
#  11  LandSlope      292 non-null    object
#  12  Neighborhood   292 non-null    object
#  13  Condition1     292 non-null    object
#  14  Condition2     292 non-null    object
#  15  BldgType       292 non-null    object
#  16  HouseStyle     292 non-null    object
# ...

# %%
df1.isnull().sum()#checking null values in the dataset
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage      45
# LotArea           0
#                  ..
# MiscVal           0
# MoSold            0
# YrSold            0
# SaleType          0
# SaleCondition     0
# Length: 80, dtype: int64

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df1.isnull())
plt.show()

# %% [markdown]
# Their are so many null values are their.So we have to remove null values according to our data descriptions

# %%
cat_columns=[i for i in df1.columns if df1[i].dtypes=='O']#extract object type feature
num_columns=[i for i in df1.columns if df1[i].dtypes!='O']#extract numerical type feature

# %% [markdown]
# # Checking missing Values

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df1[cat_columns].isnull())
plt.show()

# %%
df1[cat_columns].isnull().sum()
# Out:
# MSZoning           0
# Street             0
# Alley            278
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         1
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual           7
# BsmtCond           7
# BsmtExposure       7
# BsmtFinType1       7
# BsmtFinType2       7
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         1
# KitchenQual        0
# Functional         0
# FireplaceQu      139
# GarageType        17
# GarageFinish      17
# GarageQual        17
# GarageCond        17
# PavedDrive         0
# Fence            248
# MiscFeature      282
# SaleType           0
# SaleCondition      0
# dtype: int64

# %%
df1['Alley'].fillna('NA',inplace=True)#replace null values with NA as no alley acess
df1['MasVnrType'].fillna('None',inplace=True)#replace null values with None
df1['BsmtQual'].fillna('TA',inplace=True)#replace null values with mode of the column
df1['BsmtCond'].fillna('TA',inplace=True)#replace null values with mode of the column
df1['BsmtExposure'].fillna('No',inplace=True)#replace null values with mode of the column
df1['BsmtFinType1'].fillna('Unf',inplace=True)#replace null values with mode of the column
df1['BsmtFinType2'].fillna('Unf',inplace=True)#replace null values with mode of the column
df1['FireplaceQu'].fillna('NA',inplace=True)#replace null values with NA(as not available) of the column
df1['GarageType'].fillna('NA',inplace=True)#replace null values with NA(as not available) of the column
df1['GarageFinish'].fillna('NA',inplace=True)#replace null values with NA(as garrage not available) of the column
df1['GarageQual'].fillna('NA',inplace=True)#replace null values with NA(as garrage not available) of the column
df1['GarageCond'].fillna('NA',inplace=True)#replace null values with NA(as garrage not available) of the column
df1['PoolQC'].fillna('NA',inplace=True)#replace null values with NA(as pool not available) of the column
df1['Fence'].fillna('NA',inplace=True)#replace null values with NA(as Fence not available) of the column
df1['MiscFeature'].fillna('NA',inplace=True)#replace null values with NA(as not available)
df1['Electrical']=df1['Electrical'].fillna('SBrkr')

# %%
df1['GarageYrBlt']=df1['GarageYrBlt'].fillna(df1['YearBuilt'])

# %%
df1['LotFrontage']=df1['LotFrontage'].fillna(df1['LotFrontage'].mean())#replace null values with their mean
df1['MasVnrArea']=df1['MasVnrArea'].fillna(df1['MasVnrArea'].mean())#replace null values with their mean

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df1.isnull())
plt.show()

# %% [markdown]
# We have removed all the null values

# %% [markdown]
# # Checking Outlier

# %%
for i in df1[num_columns].columns:
    sns.boxplot(df1[num_columns][i])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-406-6d96512592f1> in <module>
#       1 for i in df1[num_columns].columns:
# ----> 2     sns.boxplot(df1[num_columns][i])
#       3     plt.show()
#
# ~\anacon\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2239     kwargs.update(dict(whis=whis))
#    2240
# -> 2241     plotter.plot(ax, kwargs)
#    2242     return ax
#    2243
#
# ~\anacon\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     537     def plot(self, ax, boxplot_kws):
#     538         """Make the plot."""
# --> 539         self.draw_boxplot(ax, boxplot_kws)
#     540         self.annotate_axes(ax)
#     541         if self.orient == "h":
#
# ...

# %%
df1[df1['LotArea']>140000]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 273  314          20       RL    150.00000   215245   Pave    NA      IR3
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 273         Low    AllPub    Inside       Sev       Timber       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 273       Norm     1Fam     1Story            7            5       1965
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 273          1965       Hip  CompShg     BrkFace     BrkFace       None
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 273     0.00000        TA        TA     CBlock       Gd       TA           Gd
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 273          ALQ        1236          Rec         820         80         2136
#
# ...

# %%
#We have to drop this row.
df1=df1.drop(273,axis=0)
df1=df1.reset_index()
df1=df1.drop('index',axis=1)
df1
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL     86.00000    14157   Pave    NA      IR1
# 1    1018         120       RL     66.42510     5814   Pave    NA      IR1
# 2     929          20       RL     66.42510    11838   Pave    NA      Reg
# 3    1148          70       RL     75.00000    12000   Pave    NA      Reg
# 4    1227          60       RL     86.00000    14598   Pave    NA      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 286    83          20       RL     78.00000    10206   Pave    NA      Reg
# 287  1048          20       RL     57.00000     9245   Pave    NA      IR2
# 288    17          20       RL     66.42510    11241   Pave    NA      IR1
# 289   523          50       RM     50.00000     5000   Pave    NA      Reg
# 290  1379         160       RM     21.00000     1953   Pave    NA      Reg
#
# ...

# %% [markdown]
# # Checking Skewness

# %%
for i in df1[['LotFrontage','LotArea','1stFlrSF','GrLivArea']].columns:
    sns.distplot(df1[['LotFrontage','LotArea','1stFlrSF','GrLivArea']][i])
    plt.show()

# %%
df[['LotFrontage','LotArea','1stFlrSF','GrLivArea']].skew()
# Out:
# LotFrontage    0.13722
# LotArea       -0.56224
# 1stFlrSF       0.03862
# GrLivArea      0.00101
# dtype: float64

# %%
df1['LotArea']=np.log(df1['LotArea'])

# %% [markdown]
# Skewness has been removed from test dataset

# %%
#Converting all catagorical features to numeric using ordinalencoder
from sklearn.preprocessing import OrdinalEncoder
od=OrdinalEncoder()
for i in df1.columns:
    if df1[i].dtypes==object:
        df1[i]=od.fit_transform(df1[[i]])

# %%
df1=df1.drop(['Id','Utilities'],axis=1)#we have to drop id column(as it is unique) and Utilities column(as it has only one value)
df1
# Out:
#      MSSubClass  MSZoning  LotFrontage  LotArea  Street   Alley  LotShape  \
# 0            20   2.00000     86.00000  9.55796 1.00000 1.00000   0.00000
# 1           120   2.00000     66.42510  8.66802 1.00000 1.00000   0.00000
# 2            20   2.00000     66.42510  9.37907 1.00000 1.00000   3.00000
# 3            70   2.00000     75.00000  9.39266 1.00000 1.00000   3.00000
# 4            60   2.00000     86.00000  9.58864 1.00000 1.00000   0.00000
# ..          ...       ...          ...      ...     ...     ...       ...
# 286          20   2.00000     78.00000  9.23073 1.00000 1.00000   3.00000
# 287          20   2.00000     57.00000  9.13184 1.00000 1.00000   1.00000
# 288          20   2.00000     66.42510  9.32732 1.00000 1.00000   0.00000
# 289          50   3.00000     50.00000  8.51719 1.00000 1.00000   3.00000
# 290         160   3.00000     21.00000  7.57712 1.00000 1.00000   3.00000
#
#      LandContour  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# ...

# %%
#we have to use scaling of dataset to make in a same range
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x=scaler.fit_transform(df1)

# %% [markdown]
# # Predict test dataset

# %%
import joblib
pred=joblib.load('price.pkl')

# %%
y_test_pred=pred.predict(x)

# %%
pred=pd.DataFrame()
pred['SalePrice']=y_test_pred
pred
# Out:
#        SalePrice
# 0   481608.58232
# 1   338371.71639
# 2   381024.42337
# 3   292468.19915
# 4   370666.56840
# ..           ...
# 286 371963.77595
# 287 239537.78524
# 288 263732.36981
# 289 307218.76776
# 290 201043.94049
#
# [291 rows x 1 columns]
